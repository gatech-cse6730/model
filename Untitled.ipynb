# %%
"""
Code to write:
    Pedestrian class
    Node class
    Intersection class
    Driver/Simulation Executor class
    Visualization class
"""
        
class Node:
    """ Implementation of the Node structure in our graph. """
    
    """ 
    Creates a new Node. 
    
    Args:
      node_type: String. One of 'enter', 'exit', 'sidewalk', 'crosswalk'.
      x: Integer. The x-coordinate of the node in the grid.
      y: Integer. The y-coordinate of the node in the grid.
      
    Returns:
      A new Node object.
    
    """
    def __init__(self, node_id, node_type, x, y):
        # A unique identifier for the node.
        self.node_id = node_id
        
        # The node type.
        self.node_type = node_type
        
        # X and y coordinates for the node in the grid.
        self.x = x
        self.y = y
        
        # Initialize a dictionary to hold the next node in the shortest path
        # for each destination.
        self.paths = {}
        
        # Array of Node neighbors.
        self.neighbors = {}
        
        # By default, the node is not available (i.e., occupied).
        self.available = True
        
    def get_next_node(self, dest, node_dict):
        next_node_id = self.paths[dest.node_id]
        
        return node_dict[next_node_id]
        
#     def set_available(self, bool_val):
#         self.available = bool_val
    
#     def set_neighbors(self, neighbors):
#         pass
    
#     def get_neighbors(self):
#         return self.neighbors
    
class Edge:
    def __init__(self, node_a, node_b, weight):
        self.node_a = node_a
        self.node_b = node_b
        self.weight = weight

# %%
class Intersection:
    """ Implements an intersection """
    # Allen to implement
    def __init__(self):
        pass
    
    def close_me():
        pass
    
    def open_me():
        pass

# %%
class Pedestrian:
    """ Implements a pedestrian. """
    
    """ 
    Creates a new Pedestrian. 
    
    Args:
      current: Node. A Node object corresponding to the current location of the
        pedestrian.
      destination: Node. A Node object corresponding to the destination node.
      speed: Integer. Number of grid cells traversed per time step. 
      
    Returns:
      A new Pedestrian object.
    
    """
    def __init__(self, current, destination, speed, node_dict):
        # The current location of the pedestrian, as a Node.
        self.current = current
        
        # Set the current node as unavailable.
        self.current.available = False
        
        # The pedestrian's final destination, as a Node.
        self.destination = destination
        
        # The speed of the pedestrian, formulated as an integer number of 
        # grid cells traversed per time step.
        self.speed = speed
        
        # The desired next node to move to.
        self.target_next = current.get_next_node(self.destination, node_dict)
        
        # Whether the pedestrian has completed egress (i.e., exited the SUI).
        self.egress_complete = False
    
    def move(self, node, node_dict, type_map):
        if not node.available:
            return
        
        # The current node is now available.
        self.current.available = True
        
        # Update the current node to the new node.
        self.current = node
        
        # If current is a destination node,
        if self.current.node_type == type_map['exit']:
            # Egress is completed.
            self.egress_complete = True
        else:
            # Set the new current node to unavailable.
            self.current.available = False

            # Update the target next.
            self.target_next = node.get_next_node(self.destination, node_dict)
        
        return self

# %%
# Dijkstra's algorithm for shortest paths.
# Implementation adapted from online version published by David Eppstein, UC Irvine, 4 April 2002.

from priodict import priorityDictionary

class ShortestPath:
    def __init__(self, graph, start, end):
        self.graph = graph
        self.start = start
        self.end = end
        
    def next_node(self): 
        try:
            shortest_path = self.shortest_path(self.graph, self.start, self.end)
        except Exception:
            return None
        
        return shortest_path[1]

    def dijkstra(self, G, start, end=None):
        """
        Find shortest paths from the  start vertex to all vertices nearer than or equal to the end.

        The input graph G is assumed to have the following representation:
        A vertex can be any object that can be used as an index into a dictionary.
        G is a dictionary, indexed by vertices.  For any vertex v, G[v] is itself a dictionary,
        indexed by the neighbors of v.  For any edge v->w, G[v][w] is the length of the edge.
        This is related to the representation in <http://www.python.org/doc/essays/graphs.html>
        where Guido van Rossum suggests representing graphs as dictionaries mapping vertices
        to lists of outgoing edges, however dictionaries of edges have many advantages over lists:
        they can store extra information (here, the lengths), they support fast existence tests,
        and they allow easy modification of the graph structure by edge insertion and removal.
        Such modifications are not needed here but are important in many other graph algorithms.
        Since dictionaries obey iterator protocol, a graph represented as described here could
        be handed without modification to an algorithm expecting Guido's graph representation.

        Of course, G and G[v] need not be actual Python dict objects, they can be any other
        type of object that obeys dict protocol, for instance one could use a wrapper in which vertices
        are URLs of web pages and a call to G[v] loads the web page and finds its outgoing links.

        The output is a pair (D,P) where D[v] is the distance from start to v and P[v] is the
        predecessor of v along the shortest path from s to v.

        Dijkstra's algorithm is only guaranteed to work correctly when all edge lengths are positive.
        This code does not verify this property for all edges (only the edges examined until the end
        vertex is reached), but will correctly compute shortest paths even for some graphs with negative
        edges, and will raise an exception if it discovers that a negative edge has caused it to make a mistake.
        """

        D = {}	# dictionary of final distances
        P = {}	# dictionary of predecessors
        Q = priorityDictionary()	# estimated distances of non-final vertices
        Q[start] = 0

        for v in Q:
            D[v] = Q[v]
            if v == end: break

            for w in G[v]:
                vwLength = D[v] + G[v][w]
                if w in D:
                    if vwLength < D[w]:
                        raise ValueError, "Dijkstra: found better path to already-final vertex"
                elif w not in Q or vwLength < Q[w]:
                    Q[w] = vwLength
                    P[w] = v

        return (D,P)

    def shortest_path(self, G, start, end):
        """
        Find a single shortest path from the given start vertex to the given end vertex.
        The input has the same conventions as Dijkstra().
        The output is a list of the vertices in order along the shortest path.
        """

        D,P = self.dijkstra(G,start,end)
        Path = []
        while 1:
            Path.append(end)
            if end == start: break
            end = P[end]
        Path.reverse()
        return Path

# %%
import csv

class Reader(object):
    def __init__(self, filename):
        self.filename = filename
        
        return self.process()
    
    def process(self):
        # Override in subclass.
        pass
    
class NodeReader(Reader):
    def __init__(self, filename):
        # Initialize a node container and a node dictionary.
        self.nodes = []
        self.node_dict = {}
        
        # Call __init__ on the parent class.
        super(NodeReader, self).__init__(filename)
    
    def process(self):
        with open(self.filename, 'rb') as csvfile:
            # Skip the first line.
            next(csvfile)

            # Create a CSV reader.
            reader = csv.reader(csvfile, delimiter=',')
            
            for indx, row in enumerate(reader):
                # The node_id for the Node will be indx.
                node_id = indx 
                
                # Node type.
                node_type = int(row[6])
                
                # X and y coordinates.
                x = int(row[0])
                y = int(row[1])
                
                # Create a new node.
                newnode = Node(node_id, node_type, x, y)
                
                # Append it to the nodes array.
                self.nodes.append(newnode)
                
                # Add an entry in the node dictionary.
                self.node_dict[node_id] = newnode
                
        return self
        
class EdgeReader(Reader):
    def __init__(self, filename): 
        # Initialize an edges container.
        self.edges = []
        
        # Call __init__ on the parent class.
        super(EdgeReader, self).__init__(filename)
        
    def process(self):
        with open(self.filename, 'rb') as csvfile:
            # Skip the first line.
            next(csvfile)

            # Create a CSV reader.
            reader = csv.reader(csvfile, delimiter=',')
            
            for row in reader:
                # The node_a and node_b corresponding to node_ids.
                node_a = int(row[0])
                node_b = int(row[1])
                
                # The weight is a float value that will be used for computations.
                weight = float(row[2])
                
                # Create a new edge.
                newedge = Edge(node_a, node_b, weight)
                
                # Append it to the edges array.
                self.edges.append(newedge)
        
        return self
        
class Grid:    
    def __init__(self, max_rows, max_cols, node_file, edge_file, type_map):
        # Save some important attributes.
        self.max_rows = max_rows
        self.max_cols = max_cols
        self.node_file = node_file
        self.edge_file = edge_file
        self.type_map = type_map
        
        # Perform initialization of the gridspace.
        self.initialize_grid()
        self.initialize_nodes()
        self.initialize_edges()
        self.set_paths()
        
    def initialize_grid(self):
        # Create a grid with the given number of rows, cols.
        self.grid = [[0 for x in range(self.max_cols)] for x in range(self.max_rows)]
        
    def initialize_nodes(self):
        reader = NodeReader(self.node_file)
        
        # Save the node dict for later lookups.
        self.node_dict = reader.node_dict
        
        # Save off the node array.
        self.nodes = reader.nodes
        
        # Initialize a list container of entrance nodes.
        self.entrance_nodes = []
        
        # Initialize a list container of destination nodes.
        self.destination_nodes = []
        
        # Iterate through the returned nodes, 
        for node in self.nodes:  
            # If the node is an entrance node, add it to the entrance nodes list.
            if node.node_type == self.type_map['entrance']:
                self.entrance_nodes.append(node)
            # If the node is an exit node, add it to the exit nodes list.
            elif node.node_type == self.type_map['exit']:
                self.destination_nodes.append(node)
            
            # Ad each node to the grid in the appropriate location.
            self.grid[node.y-1][node.x-1] = node
            
    def initialize_edges(self):
        reader = EdgeReader(self.edge_file)
        
        # Save off the edges array.
        edges = reader.edges
        
        for edge in edges:
            # Look up the first node.
            node_a = self.node_dict[edge.node_a]
            
            # Look up the second node to make sure it exists.
            node_b = self.node_dict[edge.node_b]
            
            # Add a new entry to node a's neighbors dict for node b, setting it
            # to the weight.
            node_a.neighbors[node_b.node_id] = edge.weight
            
            # Added to make undirected.
            node_b.neighbors[node_a.node_id] = edge.weight
            
        # Initialize a dictionary to store just the neighbors.
        self.neighbors_dict = {}
        
        # For every entry in the node dictionary,
        for node_id, node_obj in self.node_dict.iteritems():
            # Save just the neighbors.
            self.neighbors_dict[node_id] = node_obj.neighbors
            
    def set_paths(self):
        num_nodes = len(self.nodes)
        
        for indx, node in enumerate(self.nodes):
            if node.node_type == 4:
                continue
            
            node_id = node.node_id
            
            for destination in self.destination_nodes:
                destination_node_id = destination.node_id
                
                node.paths[destination_node_id] = ShortestPath(self.neighbors_dict, 
                                                               node_id, 
                                                               destination_node_id).next_node()
                
            percent_done = ((indx+1)/float(num_nodes))*100
            print('%.2f percent done.' % percent_done)

# %%
max_rows = 66
max_cols = 139

type_map = { 'sidewalk': 1, 'crosswalk': 2, 'entrance': 3, 'exit': 4 }
grid = Grid(max_rows, max_cols, 'playMat.png.vertex.stripped', 'playMat.png.edge.stripped', type_map)
# Out:
# 0.04 percent done.
# 0.08 percent done.
# 0.13 percent done.
# 0.17 percent done.
# 0.21 percent done.
# 0.25 percent done.
# 0.29 percent done.
# 0.34 percent done.
# 0.38 percent done.
# 0.42 percent done.
# 0.46 percent done.
# 0.50 percent done.
# 0.55 percent done.
# 0.59 percent done.
# 0.63 percent done.
# 0.67 percent done.
# 0.72 percent done.
# 0.76 percent done.
# 0.80 percent done.
# 0.84 percent done.
# 0.88 percent done.
# 0.93 percent done.
# 0.97 percent done.
# 1.01 percent done.
# 1.05 percent done.
# 1.09 percent done.
# 1.14 percent done.
# 1.18 percent done.
# 1.22 percent done.
# 1.26 percent done.
# 1.30 percent done.
# 1.35 percent done.
# 1.39 percent done.
# 1.43 percent done.
# 1.47 percent done.
# 1.51 percent done.
# 1.56 percent done.
# 1.60 percent done.
# 1.64 percent done.
# 1.85 percent done.
# 1.89 percent done.
# 1.94 percent done.
# 1.98 percent done.
# 2.02 percent done.
# 2.06 percent done.
# 2.10 percent done.
# 2.15 percent done.
# 2.19 percent done.
# 2.23 percent done.
# 2.27 percent done.
# 2.31 percent done.
# 2.36 percent done.
# 2.40 percent done.
# 2.44 percent done.
# 2.48 percent done.
# 2.52 percent done.
# 2.57 percent done.
# 2.61 percent done.
# 2.65 percent done.
# 2.69 percent done.
# 2.73 percent done.
# 2.78 percent done.
# 2.82 percent done.
# 2.86 percent done.
# 2.90 percent done.
# 2.94 percent done.
# 2.99 percent done.
# 3.03 percent done.
# 3.07 percent done.
# 3.11 percent done.
# 3.16 percent done.
# 3.20 percent done.
# 3.24 percent done.
# 3.28 percent done.
# 3.32 percent done.
# 3.37 percent done.
# 3.41 percent done.
# 3.45 percent done.
# 3.49 percent done.
# 3.53 percent done.
# 3.58 percent done.
# 3.62 percent done.
# 3.66 percent done.
# 3.70 percent done.
# 3.74 percent done.
# 3.79 percent done.
# 3.83 percent done.
# 3.87 percent done.
# 3.91 percent done.
# 3.95 percent done.
# 4.00 percent done.
# 4.04 percent done.
# 4.08 percent done.
# 4.12 percent done.
# 4.16 percent done.
# 4.21 percent done.
# 4.25 percent done.
# 4.29 percent done.
# 4.33 percent done.
# 4.38 percent done.
# 4.42 percent done.
# 4.46 percent done.
# 4.50 percent done.
# 4.54 percent done.
# 4.59 percent done.
# 4.63 percent done.
# 4.67 percent done.
# 4.71 percent done.
# 4.75 percent done.
# 4.80 percent done.
# 4.84 percent done.
# 4.88 percent done.
# 4.92 percent done.
# 4.96 percent done.
# 5.01 percent done.
# 5.05 percent done.
# 5.09 percent done.
# 5.13 percent done.
# 5.17 percent done.
# 5.22 percent done.
# 5.26 percent done.
# 5.30 percent done.
# 5.34 percent done.
# 5.38 percent done.
# 5.43 percent done.
# 5.47 percent done.
# 5.51 percent done.
# 5.55 percent done.
# 5.60 percent done.
# 5.64 percent done.
# 5.68 percent done.
# 5.72 percent done.
# 5.76 percent done.
# 5.81 percent done.
# 5.85 percent done.
# 5.89 percent done.
# 5.93 percent done.
# 5.97 percent done.
# 6.02 percent done.
# 6.06 percent done.
# 6.10 percent done.
# 6.14 percent done.
# 6.18 percent done.
# 6.23 percent done.
# 6.27 percent done.
# 6.31 percent done.
# 6.35 percent done.
# 6.39 percent done.
# 6.44 percent done.
# 6.48 percent done.
# 6.52 percent done.
# 6.56 percent done.
# 6.60 percent done.
# 6.65 percent done.
# 6.69 percent done.
# 6.73 percent done.
# 6.77 percent done.
# 6.82 percent done.
# 6.86 percent done.
# 6.90 percent done.
# 6.94 percent done.
# 6.98 percent done.
# 7.03 percent done.
# 7.07 percent done.
# 7.11 percent done.
# 7.15 percent done.
# 7.19 percent done.
# 7.24 percent done.
# 7.28 percent done.
# 7.32 percent done.
# 7.36 percent done.
# 7.40 percent done.
# 7.45 percent done.
# 7.49 percent done.
# 7.53 percent done.
# 7.57 percent done.
# 7.61 percent done.
# 7.66 percent done.
# 7.70 percent done.
# 7.74 percent done.
# 7.78 percent done.
# 7.82 percent done.
# 7.87 percent done.
# 7.91 percent done.
# 7.95 percent done.
# 7.99 percent done.
# 8.04 percent done.
# 8.08 percent done.
# 8.12 percent done.
# 8.16 percent done.
# 8.20 percent done.
# 8.25 percent done.
# 8.29 percent done.
# 8.33 percent done.
# 8.37 percent done.
# 8.41 percent done.
# 8.46 percent done.
# 8.50 percent done.
# 8.54 percent done.
# 8.58 percent done.
# 8.62 percent done.
# 8.67 percent done.
# 8.71 percent done.
# 8.75 percent done.
# 8.79 percent done.
# 8.83 percent done.
# 8.88 percent done.
# 8.92 percent done.
# 8.96 percent done.
# 9.00 percent done.
# 9.05 percent done.
# 9.09 percent done.
# 9.13 percent done.
# 9.17 percent done.
# 9.21 percent done.
# 9.26 percent done.
# 9.30 percent done.
# 9.34 percent done.
# 9.38 percent done.
# 9.42 percent done.
# 9.47 percent done.
# 9.51 percent done.
# 9.55 percent done.
# 9.59 percent done.
# 9.63 percent done.
# 9.68 percent done.
# 9.72 percent done.
# 9.76 percent done.
# 9.80 percent done.
# 9.84 percent done.
# 9.89 percent done.
# 9.93 percent done.
# 9.97 percent done.
# 10.01 percent done.
# 10.05 percent done.
# 10.10 percent done.
# 10.14 percent done.
# 10.18 percent done.
# 10.22 percent done.
# 10.27 percent done.
# 10.31 percent done.
# 10.35 percent done.
# 10.39 percent done.
# 10.43 percent done.
# 10.48 percent done.
# 10.52 percent done.
# 10.56 percent done.
# 10.60 percent done.
# 10.64 percent done.
# 10.69 percent done.
# 10.73 percent done.
# 10.77 percent done.
# 10.81 percent done.
# 10.85 percent done.
# 10.90 percent done.
# 10.94 percent done.
# 10.98 percent done.
# 11.02 percent done.
# 11.06 percent done.
# 11.11 percent done.
# 11.15 percent done.
# 11.19 percent done.
# 11.23 percent done.
# 11.27 percent done.
# 11.32 percent done.
# 11.36 percent done.
# 11.40 percent done.
# 11.44 percent done.
# 11.49 percent done.
# 11.53 percent done.
# 11.57 percent done.
# 11.61 percent done.
# 11.65 percent done.
# 11.70 percent done.
# 11.74 percent done.
# 11.78 percent done.
# 11.82 percent done.
# 11.86 percent done.
# 11.91 percent done.
# 11.95 percent done.
# 11.99 percent done.
# 12.03 percent done.
# 12.07 percent done.
# 12.12 percent done.
# 12.16 percent done.
# 12.20 percent done.
# 12.24 percent done.
# 12.28 percent done.
# 12.33 percent done.
# 12.37 percent done.
# 12.41 percent done.
# 12.45 percent done.
# 12.49 percent done.
# 12.54 percent done.
# 12.58 percent done.
# 12.62 percent done.
# 12.66 percent done.
# 12.71 percent done.
# 12.75 percent done.
# 12.79 percent done.
# 12.83 percent done.
# 12.87 percent done.
# 12.92 percent done.
# 12.96 percent done.
# 13.00 percent done.
# 13.04 percent done.
# 13.08 percent done.
# 13.13 percent done.
# 13.17 percent done.
# 13.21 percent done.
# 13.25 percent done.
# 13.29 percent done.
# 13.34 percent done.
# 13.38 percent done.
# 13.42 percent done.
# 13.46 percent done.
# 13.50 percent done.
# 13.55 percent done.
# 13.59 percent done.
# 13.63 percent done.
# 13.67 percent done.
# 13.71 percent done.
# 13.76 percent done.
# 13.80 percent done.
# 13.84 percent done.
# 13.88 percent done.
# 13.93 percent done.
# 13.97 percent done.
# 14.01 percent done.
# 14.05 percent done.
# 14.09 percent done.
# 14.14 percent done.
# 14.18 percent done.
# 14.22 percent done.
# 14.26 percent done.
# 14.30 percent done.
# 14.35 percent done.
# 14.39 percent done.
# 14.43 percent done.
# 14.47 percent done.
# 14.51 percent done.
# 14.56 percent done.
# 14.60 percent done.
# 14.64 percent done.
# 14.68 percent done.
# 14.72 percent done.
# 14.77 percent done.
# 14.81 percent done.
# 14.85 percent done.
# 14.89 percent done.
# 14.93 percent done.
# 14.98 percent done.
# 15.02 percent done.
# 15.06 percent done.
# 15.10 percent done.
# 15.15 percent done.
# 15.19 percent done.
# 15.23 percent done.
# 15.27 percent done.
# 15.31 percent done.
# 15.36 percent done.
# 15.40 percent done.
# 15.44 percent done.
# 15.48 percent done.
# 15.52 percent done.
# 15.57 percent done.
# 15.61 percent done.
# 15.65 percent done.
# 15.69 percent done.
# 15.73 percent done.
# 15.78 percent done.
# 15.82 percent done.
# 15.86 percent done.
# 15.90 percent done.
# 15.94 percent done.
# 15.99 percent done.
# 16.03 percent done.
# 16.07 percent done.
# 16.11 percent done.
# 16.15 percent done.
# 16.20 percent done.
# 16.24 percent done.
# 16.28 percent done.
# 16.32 percent done.
# 16.37 percent done.
# 16.41 percent done.
# 16.45 percent done.
# 16.49 percent done.
# 16.53 percent done.
# 16.58 percent done.
# 16.62 percent done.
# 16.66 percent done.
# 16.70 percent done.
# 16.74 percent done.
# 16.79 percent done.
# 16.83 percent done.
# 16.87 percent done.
# 16.91 percent done.
# 16.95 percent done.
# 17.00 percent done.
# 17.04 percent done.
# 17.08 percent done.
# 17.12 percent done.
# 17.16 percent done.
# 17.21 percent done.
# 17.25 percent done.
# 17.29 percent done.
# 17.33 percent done.
# 17.37 percent done.
# 17.42 percent done.
# 17.46 percent done.
# 17.50 percent done.
# 17.54 percent done.
# 17.59 percent done.
# 17.63 percent done.
# 17.67 percent done.
# 17.71 percent done.
# 17.75 percent done.
# 17.80 percent done.
# 17.84 percent done.
# 17.88 percent done.
# 17.92 percent done.
# 17.96 percent done.
# 18.01 percent done.
# 18.05 percent done.
# 18.09 percent done.
# 18.13 percent done.
# 18.17 percent done.
# 18.22 percent done.
# 18.26 percent done.
# 18.30 percent done.
# 18.34 percent done.
# 18.38 percent done.
# 18.43 percent done.
# 18.47 percent done.
# 18.51 percent done.
# 18.55 percent done.
# 18.59 percent done.
# 18.64 percent done.
# 18.68 percent done.
# 18.72 percent done.
# 18.76 percent done.
# 18.81 percent done.
# 18.85 percent done.
# 18.89 percent done.
# 18.93 percent done.
# 18.97 percent done.
# 19.02 percent done.
# 19.06 percent done.
# 19.10 percent done.
# 19.14 percent done.
# 19.18 percent done.
# 19.23 percent done.
# 19.27 percent done.
# 19.31 percent done.
# 19.35 percent done.
# 19.39 percent done.
# 19.44 percent done.
# 19.48 percent done.
# 19.52 percent done.
# 19.56 percent done.
# 19.60 percent done.
# 19.65 percent done.
# 19.69 percent done.
# 19.73 percent done.
# 19.77 percent done.
# 19.81 percent done.
# 19.86 percent done.
# 19.90 percent done.
# 19.94 percent done.
# 19.98 percent done.
# 20.03 percent done.
# 20.07 percent done.
# 20.11 percent done.
# 20.15 percent done.
# 20.19 percent done.
# 20.24 percent done.
# 20.28 percent done.
# 20.32 percent done.
# 20.36 percent done.
# 20.40 percent done.
# 20.45 percent done.
# 20.49 percent done.
# 20.53 percent done.
# 20.57 percent done.
# 20.61 percent done.
# 20.66 percent done.
# 20.70 percent done.
# 20.74 percent done.
# 20.78 percent done.
# 20.82 percent done.
# 20.87 percent done.
# 20.91 percent done.
# 20.95 percent done.
# 20.99 percent done.
# 21.03 percent done.
# 21.08 percent done.
# 21.12 percent done.
# 21.16 percent done.
# 21.20 percent done.
# 21.25 percent done.
# 21.29 percent done.
# 21.33 percent done.
# 21.37 percent done.
# 21.41 percent done.
# 21.46 percent done.
# 21.50 percent done.
# 21.54 percent done.
# 21.58 percent done.
# 21.62 percent done.
# 21.67 percent done.
# 21.71 percent done.
# 21.75 percent done.
# 21.79 percent done.
# 21.83 percent done.
# 21.88 percent done.
# 21.92 percent done.
# 21.96 percent done.
# 22.00 percent done.
# 22.04 percent done.
# 22.09 percent done.
# 22.13 percent done.
# 22.17 percent done.
# 22.21 percent done.
# 22.25 percent done.
# 22.30 percent done.
# 22.34 percent done.
# 22.38 percent done.
# 22.42 percent done.
# 22.47 percent done.
# 22.51 percent done.
# 22.55 percent done.
# 22.59 percent done.
# 22.63 percent done.
# 22.68 percent done.
# 22.72 percent done.
# 22.76 percent done.
# 22.80 percent done.
# 22.84 percent done.
# 22.89 percent done.
# 22.93 percent done.
# 22.97 percent done.
# 23.01 percent done.
# 23.05 percent done.
# 23.10 percent done.
# 23.14 percent done.
# 23.18 percent done.
# 23.22 percent done.
# 23.26 percent done.
# 23.31 percent done.
# 23.35 percent done.
# 23.39 percent done.
# 23.43 percent done.
# 23.47 percent done.
# 23.52 percent done.
# 23.56 percent done.
# 23.60 percent done.
# 23.64 percent done.
# 23.69 percent done.
# 23.73 percent done.
# 23.77 percent done.
# 23.81 percent done.
# 23.85 percent done.
# 23.90 percent done.
# 23.94 percent done.
# 23.98 percent done.
# 24.02 percent done.
# 24.06 percent done.
# 24.11 percent done.
# 24.15 percent done.
# 24.19 percent done.
# 24.23 percent done.
# 24.27 percent done.
# 24.32 percent done.
# 24.36 percent done.
# 24.40 percent done.
# 24.44 percent done.
# 24.48 percent done.
# 24.53 percent done.
# 24.57 percent done.
# 24.61 percent done.
# 24.65 percent done.
# 24.69 percent done.
# 24.74 percent done.
# 24.78 percent done.
# 24.82 percent done.
# 24.86 percent done.
# 24.91 percent done.
# 24.95 percent done.
# 24.99 percent done.
# 25.03 percent done.
# 25.07 percent done.
# 25.12 percent done.
# 25.16 percent done.
# 25.20 percent done.
# 25.24 percent done.
# 25.28 percent done.
# 25.33 percent done.
# 25.37 percent done.
# 25.41 percent done.
# 25.45 percent done.
# 25.49 percent done.
# 25.54 percent done.
# 25.58 percent done.
# 25.62 percent done.
# 25.66 percent done.
# 25.70 percent done.
# 25.75 percent done.
# 25.79 percent done.
# 25.83 percent done.
# 25.87 percent done.
# 25.92 percent done.
# 25.96 percent done.
# 26.00 percent done.
# 26.04 percent done.
# 26.08 percent done.
# 26.13 percent done.
# 26.17 percent done.
# 26.21 percent done.
# 26.25 percent done.
# 26.29 percent done.
# 26.34 percent done.
# 26.38 percent done.
# 26.42 percent done.
# 26.46 percent done.
# 26.50 percent done.
# 26.55 percent done.
# 26.59 percent done.
# 26.63 percent done.
# 26.67 percent done.
# 26.71 percent done.
# 26.76 percent done.
# 26.80 percent done.
# 26.84 percent done.
# 26.88 percent done.
# 26.92 percent done.
# 26.97 percent done.
# 27.01 percent done.
# 27.05 percent done.
# 27.09 percent done.
# 27.14 percent done.
# 27.18 percent done.
# 27.22 percent done.
# 27.26 percent done.
# 27.30 percent done.
# 27.35 percent done.
# 27.39 percent done.
# 27.43 percent done.
# 27.47 percent done.
# 27.51 percent done.
# 27.56 percent done.
# 27.60 percent done.
# 27.64 percent done.
# 27.68 percent done.
# 27.72 percent done.
# 27.77 percent done.
# 27.81 percent done.
# 27.85 percent done.
# 27.89 percent done.
# 27.93 percent done.
# 27.98 percent done.
# 28.02 percent done.
# 28.06 percent done.
# 28.10 percent done.
# 28.14 percent done.
# 28.19 percent done.
# 28.23 percent done.
# 28.27 percent done.
# 28.31 percent done.
# 28.36 percent done.
# 28.40 percent done.
# 28.44 percent done.
# 28.48 percent done.
# 28.52 percent done.
# 28.57 percent done.
# 28.61 percent done.
# 28.65 percent done.
# 28.69 percent done.
# 28.73 percent done.
# 28.78 percent done.
# 28.82 percent done.
# 28.86 percent done.
# 28.90 percent done.
# 28.94 percent done.
# 28.99 percent done.
# 29.03 percent done.
# 29.07 percent done.
# 29.11 percent done.
# 29.15 percent done.
# 29.20 percent done.
# 29.24 percent done.
# 29.28 percent done.
# 29.32 percent done.
# 29.36 percent done.
# 29.41 percent done.
# 29.45 percent done.
# 29.49 percent done.
# 29.53 percent done.
# 29.58 percent done.
# 29.62 percent done.
# 29.66 percent done.
# 29.70 percent done.
# 29.74 percent done.
# 29.79 percent done.
# 29.83 percent done.
# 29.87 percent done.
# 29.91 percent done.
# 29.95 percent done.
# 30.00 percent done.
# 30.04 percent done.
# 30.08 percent done.
# 30.12 percent done.
# 30.16 percent done.
# 30.21 percent done.
# 30.25 percent done.
# 30.29 percent done.
# 30.33 percent done.
# 30.37 percent done.
# 30.42 percent done.
# 30.46 percent done.
# 30.50 percent done.
# 30.54 percent done.
# 30.58 percent done.
# 30.63 percent done.
# 30.67 percent done.
# 30.71 percent done.
# 30.75 percent done.
# 30.80 percent done.
# 30.84 percent done.
# 30.88 percent done.
# 30.92 percent done.
# 30.96 percent done.
# 31.01 percent done.
# 31.05 percent done.
# 31.09 percent done.
# 31.13 percent done.
# 31.17 percent done.
# 31.22 percent done.
# 31.26 percent done.
# 31.30 percent done.
# 31.34 percent done.
# 31.38 percent done.
# 31.43 percent done.
# 31.47 percent done.
# 31.51 percent done.
# 31.55 percent done.
# 31.59 percent done.
# 31.64 percent done.
# 31.68 percent done.
# 31.72 percent done.
# 31.76 percent done.
# 31.80 percent done.
# 31.85 percent done.
# 31.89 percent done.
# 31.93 percent done.
# 31.97 percent done.
# 32.02 percent done.
# 32.06 percent done.
# 32.10 percent done.
# 32.14 percent done.
# 32.18 percent done.
# 32.23 percent done.
# 32.27 percent done.
# 32.31 percent done.
# 32.35 percent done.
# 32.39 percent done.
# 32.44 percent done.
# 32.48 percent done.
# 32.52 percent done.
# 32.56 percent done.
# 32.60 percent done.
# 32.65 percent done.
# 32.69 percent done.
# 32.73 percent done.
# 32.77 percent done.
# 32.81 percent done.
# 32.86 percent done.
# 32.90 percent done.
# 32.94 percent done.
# 32.98 percent done.
# 33.02 percent done.
# 33.07 percent done.
# 33.11 percent done.
# 33.15 percent done.
# 33.19 percent done.
# 33.24 percent done.
# 33.28 percent done.
# 33.32 percent done.
# 33.36 percent done.
# 33.40 percent done.
# 33.45 percent done.
# 33.49 percent done.
# 33.53 percent done.
# 33.57 percent done.
# 33.61 percent done.
# 33.66 percent done.
# 33.70 percent done.
# 33.74 percent done.
# 33.78 percent done.
# 33.82 percent done.
# 33.87 percent done.
# 33.91 percent done.
# 33.95 percent done.
# 33.99 percent done.
# 34.03 percent done.
# 34.08 percent done.
# 34.12 percent done.
# 34.16 percent done.
# 34.20 percent done.
# 34.24 percent done.
# 34.29 percent done.
# 34.33 percent done.
# 34.37 percent done.
# 34.41 percent done.
# 34.46 percent done.
# 34.50 percent done.
# 34.54 percent done.
# 34.58 percent done.
# 34.62 percent done.
# 34.67 percent done.
# 34.71 percent done.
# 34.75 percent done.
# 34.79 percent done.
# 34.83 percent done.
# 34.88 percent done.
# 34.92 percent done.
# 34.96 percent done.
# 35.00 percent done.
# 35.04 percent done.
# 35.09 percent done.
# 35.13 percent done.
# 35.17 percent done.
# 35.21 percent done.
# 35.25 percent done.
# 35.30 percent done.
# 35.34 percent done.
# 35.38 percent done.
# 35.42 percent done.
# 35.46 percent done.
# 35.51 percent done.
# 35.55 percent done.
# 35.59 percent done.
# 35.63 percent done.
# 35.68 percent done.
# 35.72 percent done.
# 35.76 percent done.
# 35.80 percent done.
# 35.84 percent done.
# 35.89 percent done.
# 35.93 percent done.
# 35.97 percent done.
# 36.01 percent done.
# 36.05 percent done.
# 36.10 percent done.
# 36.14 percent done.
# 36.18 percent done.
# 36.22 percent done.
# 36.26 percent done.
# 36.31 percent done.
# 36.35 percent done.
# 36.39 percent done.
# 36.43 percent done.
# 36.47 percent done.
# 36.52 percent done.
# 36.56 percent done.
# 36.60 percent done.
# 36.64 percent done.
# 36.68 percent done.
# 36.73 percent done.
# 36.77 percent done.
# 36.81 percent done.
# 36.85 percent done.
# 36.90 percent done.
# 36.94 percent done.
# 36.98 percent done.
# 37.02 percent done.
# 37.06 percent done.
# 37.11 percent done.
# 37.15 percent done.
# 37.19 percent done.
# 37.23 percent done.
# 37.27 percent done.
# 37.32 percent done.
# 37.36 percent done.
# 37.40 percent done.
# 37.44 percent done.
# 37.48 percent done.
# 37.53 percent done.
# 37.57 percent done.
# 37.61 percent done.
# 37.65 percent done.
# 37.69 percent done.
# 37.74 percent done.
# 37.78 percent done.
# 37.82 percent done.
# 37.86 percent done.
# 37.90 percent done.
# 37.95 percent done.
# 37.99 percent done.
# 38.03 percent done.
# 38.07 percent done.
# 38.12 percent done.
# 38.16 percent done.
# 38.20 percent done.
# 38.24 percent done.
# 38.28 percent done.
# 38.33 percent done.
# 38.37 percent done.
# 38.41 percent done.
# 38.45 percent done.
# 38.49 percent done.
# 38.54 percent done.
# 38.58 percent done.
# 38.62 percent done.
# 38.66 percent done.
# 38.70 percent done.
# 38.75 percent done.
# 38.79 percent done.
# 38.83 percent done.
# 38.87 percent done.
# 38.91 percent done.
# 38.96 percent done.
# 39.00 percent done.
# 39.04 percent done.
# 39.08 percent done.
# 39.12 percent done.
# 39.17 percent done.
# 39.21 percent done.
# 39.25 percent done.
# 39.29 percent done.
# 39.34 percent done.
# 39.38 percent done.
# 39.42 percent done.
# 39.46 percent done.
# 39.50 percent done.
# 39.55 percent done.
# 39.59 percent done.
# 39.63 percent done.
# 39.67 percent done.
# 39.71 percent done.
# 39.76 percent done.
# 39.80 percent done.
# 39.84 percent done.
# 39.88 percent done.
# 39.92 percent done.
# 39.97 percent done.
# 40.01 percent done.
# 40.05 percent done.
# 40.09 percent done.
# 40.13 percent done.
# 40.18 percent done.
# 40.22 percent done.
# 40.26 percent done.
# 40.30 percent done.
# 40.34 percent done.
# 40.39 percent done.
# 40.43 percent done.
# 40.47 percent done.
# 40.51 percent done.
# 40.56 percent done.
# 40.60 percent done.
# 40.64 percent done.
# 40.68 percent done.
# 40.72 percent done.
# 40.77 percent done.
# 40.81 percent done.
# 40.85 percent done.
# 40.89 percent done.
# 40.93 percent done.
# 40.98 percent done.
# 41.02 percent done.
# 41.06 percent done.
# 41.10 percent done.
# 41.14 percent done.
# 41.19 percent done.
# 41.23 percent done.
# 41.27 percent done.
# 41.31 percent done.
# 41.35 percent done.
# 41.40 percent done.
# 41.44 percent done.
# 41.48 percent done.
# 41.52 percent done.
# 41.56 percent done.
# 41.61 percent done.
# 41.65 percent done.
# 41.69 percent done.
# 41.73 percent done.
# 41.78 percent done.
# 41.82 percent done.
# 41.86 percent done.
# 41.90 percent done.
# 41.94 percent done.
# 41.99 percent done.
# 42.03 percent done.
# 42.07 percent done.
# 42.11 percent done.
# 42.15 percent done.
# 42.20 percent done.
# 42.24 percent done.
# 42.28 percent done.
# 42.32 percent done.
# 42.36 percent done.
# 42.41 percent done.
# 42.45 percent done.
# 42.49 percent done.
# 42.53 percent done.
# 42.57 percent done.
# 42.62 percent done.
# 42.66 percent done.
# 42.70 percent done.
# 42.74 percent done.
# 42.79 percent done.
# 42.83 percent done.
# 42.87 percent done.
# 42.91 percent done.
# 42.95 percent done.
# 43.00 percent done.
# 43.04 percent done.
# 43.08 percent done.
# 43.12 percent done.
# 43.16 percent done.
# 43.21 percent done.
# 43.25 percent done.
# 43.29 percent done.
# 43.33 percent done.
# 43.37 percent done.
# 43.42 percent done.
# 43.46 percent done.
# 43.50 percent done.
# 43.54 percent done.
# 43.58 percent done.
# 43.63 percent done.
# 43.67 percent done.
# 43.71 percent done.
# 43.75 percent done.
# 43.79 percent done.
# 43.84 percent done.
# 43.88 percent done.
# 43.92 percent done.
# 43.96 percent done.
# 44.01 percent done.
# 44.05 percent done.
# 44.09 percent done.
# 44.13 percent done.
# 44.17 percent done.
# 44.22 percent done.
# 44.26 percent done.
# 44.30 percent done.
# 44.34 percent done.
# 44.38 percent done.
# 44.43 percent done.
# 44.47 percent done.
# 44.51 percent done.
# 44.55 percent done.
# 44.59 percent done.
# 44.64 percent done.
# 44.68 percent done.
# 44.72 percent done.
# 44.76 percent done.
# 44.80 percent done.
# 44.85 percent done.
# 44.89 percent done.
# 44.93 percent done.
# 44.97 percent done.
# 45.01 percent done.
# 45.06 percent done.
# 45.10 percent done.
# 45.14 percent done.
# 45.18 percent done.
# 45.23 percent done.
# 45.27 percent done.
# 45.31 percent done.
# 45.35 percent done.
# 45.39 percent done.
# 45.44 percent done.
# 45.48 percent done.
# 45.52 percent done.
# 45.56 percent done.
# 45.60 percent done.
# 45.65 percent done.
# 45.69 percent done.
# 45.73 percent done.
# 45.77 percent done.
# 45.81 percent done.
# 45.86 percent done.
# 45.90 percent done.
# 45.94 percent done.
# 45.98 percent done.
# 46.02 percent done.
# 46.07 percent done.
# 46.11 percent done.
# 46.15 percent done.
# 46.19 percent done.
# 46.23 percent done.
# 46.28 percent done.
# 46.32 percent done.
# 46.36 percent done.
# 46.40 percent done.
# 46.45 percent done.
# 46.49 percent done.
# 46.53 percent done.
# 46.57 percent done.
# 46.61 percent done.
# 46.66 percent done.
# 46.70 percent done.
# 46.74 percent done.
# 46.78 percent done.
# 46.82 percent done.
# 46.87 percent done.
# 46.91 percent done.
# 46.95 percent done.
# 46.99 percent done.
# 47.03 percent done.
# 47.08 percent done.
# 47.12 percent done.
# 47.16 percent done.
# 47.20 percent done.
# 47.24 percent done.
# 47.29 percent done.
# 47.33 percent done.
# 47.37 percent done.
# 47.41 percent done.
# 47.45 percent done.
# 47.50 percent done.
# 47.54 percent done.
# 47.58 percent done.
# 47.62 percent done.
# 47.67 percent done.
# 47.71 percent done.
# 47.75 percent done.
# 47.79 percent done.
# 47.83 percent done.
# 47.88 percent done.
# 47.92 percent done.
# 47.96 percent done.
# 48.00 percent done.
# 48.04 percent done.
# 48.09 percent done.
# 48.13 percent done.
# 48.17 percent done.
# 48.21 percent done.
# 48.25 percent done.
# 48.30 percent done.
# 48.34 percent done.
# 48.38 percent done.
# 48.42 percent done.
# 48.46 percent done.
# 48.51 percent done.
# 48.55 percent done.
# 48.59 percent done.
# 48.63 percent done.
# 48.67 percent done.
# 48.72 percent done.
# 48.76 percent done.
# 48.80 percent done.
# 48.84 percent done.
# 48.89 percent done.
# 48.93 percent done.
# 48.97 percent done.
# 49.01 percent done.
# 49.05 percent done.
# 49.10 percent done.
# 49.14 percent done.
# 49.18 percent done.
# 49.22 percent done.
# 49.26 percent done.
# 49.31 percent done.
# 49.35 percent done.
# 49.39 percent done.
# 49.43 percent done.
# 49.47 percent done.
# 49.52 percent done.
# 49.56 percent done.
# 49.60 percent done.
# 49.64 percent done.
# 49.68 percent done.
# 49.73 percent done.
# 49.77 percent done.
# 49.81 percent done.
# 49.85 percent done.
# 49.89 percent done.
# 49.94 percent done.
# 49.98 percent done.
# 50.02 percent done.
# 50.06 percent done.
# 50.11 percent done.
# 50.15 percent done.
# 50.19 percent done.
# 50.23 percent done.
# 50.27 percent done.
# 50.32 percent done.
# 50.36 percent done.
# 50.40 percent done.
# 50.44 percent done.
# 50.48 percent done.
# 50.53 percent done.
# 50.57 percent done.
# 50.61 percent done.
# 50.65 percent done.
# 50.69 percent done.
# 50.74 percent done.
# 50.78 percent done.
# 50.82 percent done.
# 50.86 percent done.
# 50.90 percent done.
# 50.95 percent done.
# 50.99 percent done.
# 51.03 percent done.
# 51.07 percent done.
# 51.11 percent done.
# 51.16 percent done.
# 51.20 percent done.
# 51.24 percent done.
# 51.28 percent done.
# 51.33 percent done.
# 51.37 percent done.
# 51.41 percent done.
# 51.45 percent done.
# 51.49 percent done.
# 51.54 percent done.
# 51.58 percent done.
# 51.62 percent done.
# 51.66 percent done.
# 51.70 percent done.
# 51.75 percent done.
# 51.79 percent done.
# 51.83 percent done.
# 51.87 percent done.
# 51.91 percent done.
# 51.96 percent done.
# 52.00 percent done.
# 52.04 percent done.
# 52.08 percent done.
# 52.12 percent done.
# 52.17 percent done.
# 52.21 percent done.
# 52.25 percent done.
# 52.29 percent done.
# 52.33 percent done.
# 52.38 percent done.
# 52.42 percent done.
# 52.46 percent done.
# 52.50 percent done.
# 52.55 percent done.
# 52.59 percent done.
# 52.63 percent done.
# 52.67 percent done.
# 52.71 percent done.
# 52.76 percent done.
# 52.80 percent done.
# 52.84 percent done.
# 52.88 percent done.
# 52.92 percent done.
# 52.97 percent done.
# 53.01 percent done.
# 53.05 percent done.
# 53.09 percent done.
# 53.13 percent done.
# 53.18 percent done.
# 53.22 percent done.
# 53.26 percent done.
# 53.30 percent done.
# 53.34 percent done.
# 53.39 percent done.
# 53.43 percent done.
# 53.47 percent done.
# 53.51 percent done.
# 53.55 percent done.
# 53.60 percent done.
# 53.64 percent done.
# 53.68 percent done.
# 53.72 percent done.
# 53.77 percent done.
# 53.81 percent done.
# 53.85 percent done.
# 53.89 percent done.
# 53.93 percent done.
# 53.98 percent done.
# 54.02 percent done.
# 54.06 percent done.
# 54.10 percent done.
# 54.14 percent done.
# 54.19 percent done.
# 54.23 percent done.
# 54.27 percent done.
# 54.31 percent done.
# 54.35 percent done.
# 54.40 percent done.
# 54.44 percent done.
# 54.48 percent done.
# 54.52 percent done.
# 54.56 percent done.
# 54.61 percent done.
# 54.65 percent done.
# 54.69 percent done.
# 54.73 percent done.
# 54.77 percent done.
# 54.82 percent done.
# 54.86 percent done.
# 54.90 percent done.
# 54.94 percent done.
# 54.99 percent done.
# 55.03 percent done.
# 55.07 percent done.
# 55.11 percent done.
# 55.15 percent done.
# 55.20 percent done.
# 55.24 percent done.
# 55.28 percent done.
# 55.32 percent done.
# 55.36 percent done.
# 55.41 percent done.
# 55.45 percent done.
# 55.49 percent done.
# 55.53 percent done.
# 55.57 percent done.
# 55.62 percent done.
# 55.66 percent done.
# 55.70 percent done.
# 55.74 percent done.
# 55.78 percent done.
# 55.83 percent done.
# 55.87 percent done.
# 55.91 percent done.
# 55.95 percent done.
# 55.99 percent done.
# 56.04 percent done.
# 56.08 percent done.
# 56.12 percent done.
# 56.16 percent done.
# 56.21 percent done.
# 56.25 percent done.
# 56.29 percent done.
# 56.33 percent done.
# 56.37 percent done.

# %%
from datetime import datetime
from time import sleep
import random

class Simulation:
    def __init__(self, grid, params = {}):
        self.grid = grid
        self.num_pedestrians = params.get('num_pedestrians', 500)
        
        self.target_next_dict = {node: [] for node in self.grid.nodes}
        self.seed_pedestrians()
        
    def run(self):        
        self.active_peds = []
        
        while True:
            print('Iterating.')
            
            if len(self.ped_queue) == 0 and len(self.active_peds) == 0:
                print('Finished!')
                break
            
            if len(self.ped_queue) > 0:
                print('Adding a pedestrian. Ped queue length is ', len(self.ped_queue))
                self.active_peds.append(self.pedestrians.pop(0))
            else:
                print('Something went wrong.')
                break
                
            for indx, ped in enumerate(active_peds):
                print('Iterating through active_peds, indx=', indx)
                
                # If the ped is finished,
                if ped.egress_complete:
                    # Remove her.
                    del active_peds[indx]
                    continue
                
                # Grab the ped's target next node according to the shortest path algo.
                target_next = ped.target_next
                
                # Add an entry in the node => peds dictionary, telling us that the ped
                # wants to go to that node.
                self.target_next_dict[target_next].append(ped)
                
            print('target next dict is ', self.target_next_dict)
            
            print('starting target next dict iterations...')
            
            for node, peds in target_next_dict.iteritems():
                ped_len = len(peds)
                
                print('ped len is ', ped_len)
                
                if ped_len == 0: 
                    print('continuing.')
                    # Nobody wants it. :-(. Keep going.
                    continue
                elif ped_len == 1:
                    print('giving the ped what he wants.')
                    # We're done; only one ped wants the node.
                    ped = peds[0]
                else:
                    print('selecting a random ped.')
                    # Select a ped at random to get the node.
                    ped = peds[random.randrange(0, ped_len-1)]
                    
                # Move the ped.
                ped.move(node, self.grid.node_dict, self.grid.type_map)
                print('moved the ped to ', node.node_id)
                
        print('Sim done.')
    
    def seed_pedestrians(self):
        num_entrance_nodes = len(self.grid.entrance_nodes)
        num_destination_nodes = len(self.grid.destination_nodes)
        
        self.ped_queue = [self.generate_pedestrian(num_entrance_nodes, num_destination_nodes) 
                          for i in range(self.num_pedestrians)]
        
    def generate_pedestrian(self, num_entrance_nodes, num_destination_nodes):
        # TODO: add random number generator.
        entrance_node = self.grid.entrance_nodes[random.randrange(0, num_entrance_nodes-1)]
        destination_node = self.grid.destination_nodes[random.randrange(0, num_destination_nodes-1)]
        
        # TODO: set speed (third argument) dynamically by drawing from a distribution.
        new_ped = Pedestrian(entrance_node, destination_node, 1, self.grid.node_dict)
        
        return new_ped

# %%
simulation = Simulation(grid, {'num_pedestrians': 20})
simulation.run()

# Create a queue full of N pedestrians
# While loop
# BREAK if queue empty and everyone on a destination node
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-e0a51548a6b2> in <module>()
# ----> 1 simulation = Simulation(grid, {'num_pedestrians': 20})
#       2 simulation.run()
#       3
#       4 # Create a queue full of N pedestrians
#       5 # While loop
#
# <ipython-input-78-8dbbb8052fc6> in __init__(self, grid, params)
#       9
#      10         self.target_next_dict = {node: [] for node in self.grid.nodes}
# ---> 11         self.seed_pedestrians()
#      12
#      13     def run(self):
#
# <ipython-input-78-8dbbb8052fc6> in seed_pedestrians(self)
#      77
#      78         self.ped_queue = [self.generate_pedestrian(num_entrance_nodes, num_destination_nodes)
# ---> 79                           for i in range(self.num_pedestrians)]
#      80
#      81     def generate_pedestrian(self, num_entrance_nodes, num_destination_nodes):
#
# <ipython-input-78-8dbbb8052fc6> in generate_pedestrian(self, num_entrance_nodes, num_destination_nodes)
#      85
#      86         # TODO: set speed (third argument) dynamically by drawing from a distribution.
# ---> 87         new_ped = Pedestrian(entrance_node, destination_node, 1, self.grid.node_dict)
#      88
#      89         return new_ped
#
# <ipython-input-69-6548f5984987> in __init__(self, current, destination, speed, node_dict)
#      30
#      31         # The desired next node to move to.
# ---> 32         self.target_next = current.get_next_node(self.destination, node_dict)
#      33
#      34         # Whether the pedestrian has completed egress (i.e., exited the SUI).
#
# <ipython-input-61-dcf1ba2f64f4> in get_next_node(self, dest, node_dict)
#      45
#      46     def get_next_node(self, dest, node_dict):
# ---> 47         next_node_id = self.paths[dest]
#      48
#      49         return node_dict[next_node_id]
#
# KeyError: <__main__.Node instance at 0x1111481b8>
